# %%
import numpy as np
import h5py
import math
import os
import pathlib
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import torch
import random
import torch.nn as nn
import sklearn
import collections
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
import json
from torch.optim import Adam
import pylab
from scipy.optimize import curve_fit
from google.colab import drive
drive.mount('/content/gdrive')
import sys
sys.path.insert(0,'/content/gdrive/MyDrive/Penn/Colab/Data/')
from functions import load_model, save_model, Dataset, mse_loss
from sklearn.metrics import roc_curve, auc
from IPython.display import Javascript
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Load Data

# %%
# Load Background data, which will be used for training
filename = 'BKG_dataset.h5'
with h5py.File('/content/gdrive/MyDrive/Penn/Colab/Data/BKG_dataset.h5', 'r') as file:
    X_train = np.array(file['X_train'])
    X_test = np.array(file['X_test'])
    X_val = np.array(file['X_val'])

print(X_train.shape)
# Out:
# (640000, 57)

# %%
def calculate_pT_sum(x_in):
    """Calculate the sum of the pT of all objects for each event.
    Takes in [N, 57] and returns [N]."""

    x = x_in.reshape(-1, 19, 3, 1)
    pT = x[:, 1:, 0, 0]
    pT_sum = np.sum(pT, axis=1)
    return pT_sum

# %%
def drop_data(x_in, max_events_per_bin, num_bins):
    """Drop some low pT events to create a more equalized pT distribution during training."""

    # Make a histogram of the original pT_sum
    pT_sum = calculate_pT_sum(x_in)
    freq, bin_edges = np.histogram(pT_sum, bins=num_bins)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
    indxs = np.digitize(pT_sum, bin_edges[:-1]) - 1


    # Plot histogram before dropping events
    plt.figure(figsize=(8, 4))
    plt.rcParams['axes.linewidth'] = 2.4
    plt.grid(zorder=0)
    plt.bar(bin_centers, freq, width=bin_edges[1]-bin_edges[0], color='mediumvioletred', edgecolor='k', linewidth=3, zorder=2)
    plt.yscale('log')
    plt.xlabel('Total pT in Event', fontsize=15)
    plt.ylabel('Frequency', fontsize=15)
    plt.title(f'pT Histogram Before Dropping Events', fontsize=20)
    plt.show()

    events_to_drop = []

    # Loop over the counts in each bin
    for i, count in enumerate(freq):
        if count > max_events_per_bin:
            events_in_bin = np.where(indxs == i)[0] # Indices of the events in each bin
            events_to_drop.extend(np.random.choice(events_in_bin, size=count - max_events_per_bin, replace=False)) # Indices of the events we want to drop

    # Drop the selected events
    x = np.delete(x_in, events_to_drop, axis=0)

    # Make a histogram with the new pT_sum
    pT_sum = calculate_pT_sum(x)
    freq, bin_edges = np.histogram(pT_sum, bins=num_bins)
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    # Plot histogram after dropping events
    plt.figure(figsize=(8, 4))
    plt.rcParams['axes.linewidth'] = 2.4
    plt.grid(zorder=0)
    plt.bar(bin_centers, freq, width=bin_edges[1]-bin_edges[0], color='mediumvioletred', edgecolor='k', linewidth=3, zorder=2)
    plt.yscale('log')
    plt.xlabel('Total pT in Event', fontsize=15)
    plt.ylabel('Frequency', fontsize=15)
    plt.title(f'pT Histogram After Dropping Events', fontsize=20)
    plt.show()

    return x

# %%
print(f'X_Train:')
X_train = drop_data(X_train, max_events_per_bin=1500, num_bins=3)

print(f'\nX_Val:')
X_val = drop_data(X_val, max_events_per_bin=1500, num_bins=3)
# Out:
# X_Train:
# X_Val:

# %%
print(f'train dataset: {X_train.shape}')
print(f'test dataset: {X_test.shape}')
print(f'val dataset: {X_val.shape}')
# Out:
# train dataset: (1616, 57)
# test dataset: (200000, 57)
# val dataset: (1599, 57)

# %%
# Initialize datasets
train_dataset = Dataset(X=X_train, y=X_train)
test_dataset = Dataset(X=X_test, y=X_test)
val_dataset = Dataset(X=X_val, y=X_val)

# %%
BATCH_SIZE = 32
print(f'number of batches = {len(train_dataset) // BATCH_SIZE + 1}')
# Out:
# number of batches = 51

# %%
# Initialize dataloaders
train_loader = train_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=True)
test_loader = test_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=False)
val_loader = val_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=False)
batch_X, batch_y = next(iter(train_loader))
print ("Sample batch:\n"
    f"  X: {list(batch_X.size())}\n"
    f"  y: {list(batch_y.size())}\n")
# Out:
# Sample batch:
#   X: [32, 57]
#   y: [32, 57]

# %% [markdown]
# ## DNN and Trainer Classes

# %%
class DNN_AE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        """input_dim: dimension of the input data.
        latent_dim: dimension of the latent space. Should be smaller than all of the other layers.
        num_nodes: two element array containing the number of nodes in the two hidden layers."""
        super(DNN_AE, self).__init__()

        # Encoder layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, latent_dim)

        # Decoder layers
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, input_dim)

    def forward(self, x_in):
        """Forward through the autoencoder with relu activation."""

        # Encoder
        z = F.relu(self.fc1(x_in))
        z = F.relu(self.fc2(z))

        # Decoder
        z = F.relu(self.fc3(z))
        z = self.fc4(z)
        return z

    def loss_function(self, x, y):
        # Define a mask which is False wherever an element of y is 0, True otherwise
        mask = (y != 0)

        # Apply the mask
        _x = mask * x
        _y = mask * y

        return F.mse_loss(_x, _y)

# %%
class Trainer(object):
    def __init__(self, model, num_batches_avg, loss_fn=None, optimizer=None, scheduler=None):
        """num_batches_avg: Number of batches to calculate the average loss over.
        example: if there are 625 batches, we might want to use 25, to calculate
        average loss over 25 batches."""

        #Set params
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.num_batches_avg = num_batches_avg

    def train_step(self, dataloader):
        """Train for one epoch.

        returns: average loss over most recent {num_batches_avg} batches, loss over most recent batch
        """

        self.model.train()
        current_loss = 0.0 # Average loss of most recent batch
        avg_loss = 0.0 # Average loss over a certain number of batches
        running_loss = 0.0

        # Iterate over batches in dataloader
        for i, batch in enumerate(dataloader):

            # Pass a single batch through the model and update the weights
            inputs, targets = batch
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.loss_fn(outputs, targets)
            loss.backward()
            self.optimizer.step()

            # Update loss metrics
            running_loss += loss.item()
            current_loss = loss.item()

            # Calculate the average loss
            if i % self.num_batches_avg == self.num_batches_avg - 1:
                avg_loss = running_loss / self.num_batches_avg
                running_loss = 0.0

        return avg_loss, current_loss

    def eval_step(self, dataloader):
        """validation or test step over one epoch."""

        self.model.eval()
        current_loss = 0.0 # Average loss of most recent batch
        avg_loss = 0.0 # Average loss over a certain number of batches
        running_loss = 0.0
        y_trues, model_outputs = [], []

        # Iterate over val batches
        with torch.no_grad():
            for i, batch in enumerate(dataloader):

                # Pass a single batch through the model
                inputs, y_true = batch
                outputs = self.model(inputs)
                loss = self.loss_fn(outputs, y_true)

                # Update loss metrics
                running_loss += loss.item()
                current_loss = loss.item()

                # Calculate the average loss
                if i % self.num_batches_avg == self.num_batches_avg - 1:
                    avg_loss = running_loss / self.num_batches_avg
                    running_loss = 0.0

                # Store outputs
                y_trues.extend(y_true)
                model_outputs.extend(outputs)
        return avg_loss, current_loss, np.vstack(y_trues), np.vstack(model_outputs)

    def predict_step(self, dataloader):
        """Prediction step."""
        self.model.eval()
        model_outputs = []

        # Iterate over batches
        with torch.no_grad():
            for i, batch in enumerate(dataloader):

                # Pass a single batch through the model
                inputs, targets = batch
                outputs = self.model(inputs)

                # Store outputs
                model_outputs.extend(outputs)

        return np.vstack(model_outputs)

    def train(self, num_epochs, patience, train_dataloader, val_dataloader):
        """Train the neural net."""

        best_val_loss = np.inf

        # Loop over epochs
        for epoch in range(num_epochs):

            # Steps
            avg_train_loss, last_train_loss = self.train_step(dataloader=train_dataloader)
            avg_val_loss, last_val_loss, _, _ = self.eval_step(dataloader=val_dataloader)
            self.scheduler.step(avg_val_loss)

            # Early stopping
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = self.model
                patience_counter = patience # reset patience
            else:
                patience_counter -= 1
            if not patience_counter: # 0
                print("Stoping Early!")
                break

            # Logging
            print(f'Epoch: {epoch+1} | '
            f'average train loss over most recent {self.num_batches_avg} batches: {avg_train_loss},'
            f'average val loss over most recent {self.num_batches_avg} batches: {avg_val_loss},'
            #f'learning rate: {self.optimizer.param_groups[0]['lr']:.2E},'
            f'patience counter: {patience_counter}')

        return best_model

# %% [markdown]
# ## Initialize Model and Train

# %%
# Define consts
LEARNING_RATE = 1e-3
PATIENCE = 10
NUM_EPOCHS = 100

# %%
# Initialize model
INPUT_DIM = X_train.shape[1]
HIDDEN_DIM = 16
LATENT_DIM = 4
dense_AE = DNN_AE(input_dim=INPUT_DIM, hidden_dim=HIDDEN_DIM, latent_dim=LATENT_DIM)
print(dense_AE.named_parameters)
# Out:
# <bound method Module.named_parameters of DNN_AE(
#   (fc1): Linear(in_features=57, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=4, bias=True)
#   (fc3): Linear(in_features=4, out_features=16, bias=True)
#   (fc4): Linear(in_features=16, out_features=57, bias=True)
# )>

# %%
# Initialize the loss function, optimizer and lr scheduler, trainer

def loss_fn(x, y):
    return dense_AE.loss_function(x, y)

optimizer = Adam(params=dense_AE.parameters(), lr=LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.2, patience=5, verbose=True)
trainer = Trainer(model=dense_AE, num_batches_avg=25,
                  loss_fn=loss_fn, optimizer=optimizer, scheduler=scheduler)

# %%
# Train
best_model = trainer.train(
    num_epochs=NUM_EPOCHS, patience=PATIENCE,
    train_dataloader=train_loader, val_dataloader=val_loader)
# Out:
# Epoch: 1 | average train loss over most recent 25 batches: 901.2251315307617,average val loss over most recent 25 batches: 281.5914422607422,patience counter: 10
# Epoch: 2 | average train loss over most recent 25 batches: 565.8210797119141,average val loss over most recent 25 batches: 138.1076658630371,patience counter: 10
# Epoch: 3 | average train loss over most recent 25 batches: 190.39419914245605,average val loss over most recent 25 batches: 64.82745674133301,patience counter: 10
# Epoch: 4 | average train loss over most recent 25 batches: 192.50264427185058,average val loss over most recent 25 batches: 60.128127593994144,patience counter: 10
# Epoch: 5 | average train loss over most recent 25 batches: 138.78200828552247,average val loss over most recent 25 batches: 58.23699981689453,patience counter: 10
# Epoch: 6 | average train loss over most recent 25 batches: 113.60066436767578,average val loss over most recent 25 batches: 57.81356880187988,patience counter: 10
# Epoch: 7 | average train loss over most recent 25 batches: 158.2710252380371,average val loss over most recent 25 batches: 56.45096099853516,patience counter: 10
# Epoch: 8 | average train loss over most recent 25 batches: 149.4299282836914,average val loss over most recent 25 batches: 55.23522994995117,patience counter: 10
# Epoch: 9 | average train loss over most recent 25 batches: 142.26121086120605,average val loss over most recent 25 batches: 54.13083381652832,patience counter: 10
# Epoch: 10 | average train loss over most recent 25 batches: 114.88425575256348,average val loss over most recent 25 batches: 52.941917419433594,patience counter: 10
# Epoch: 11 | average train loss over most recent 25 batches: 111.79915885925293,average val loss over most recent 25 batches: 51.00963829040527,patience counter: 10
# Epoch: 12 | average train loss over most recent 25 batches: 144.01330177307128,average val loss over most recent 25 batches: 49.77107238769531,patience counter: 10
# Epoch: 13 | average train loss over most recent 25 batches: 127.35044784545899,average val loss over most recent 25 batches: 46.963689956665036,patience counter: 10
# Epoch: 14 | average train loss over most recent 25 batches: 108.18541206359863,average val loss over most recent 25 batches: 44.89932601928711,patience counter: 10
# Epoch: 15 | average train loss over most recent 25 batches: 136.88664665222169,average val loss over most recent 25 batches: 43.302006530761716,patience counter: 10
# Epoch: 16 | average train loss over most recent 25 batches: 106.08272239685058,average val loss over most recent 25 batches: 39.52086151123047,patience counter: 10
# Epoch: 17 | average train loss over most recent 25 batches: 86.7834383392334,average val loss over most recent 25 batches: 38.110799102783204,patience counter: 10
# Epoch: 18 | average train loss over most recent 25 batches: 96.94389068603516,average val loss over most recent 25 batches: 36.28291748046875,patience counter: 10
# Epoch: 19 | average train loss over most recent 25 batches: 86.17281967163086,average val loss over most recent 25 batches: 34.23766902923584,patience counter: 10
# Epoch: 20 | average train loss over most recent 25 batches: 76.1980755996704,average val loss over most recent 25 batches: 32.35994606018066,patience counter: 10
# Epoch: 21 | average train loss over most recent 25 batches: 69.07668712615967,average val loss over most recent 25 batches: 30.976761131286622,patience counter: 10
# Epoch: 22 | average train loss over most recent 25 batches: 72.68773979187011,average val loss over most recent 25 batches: 29.18970115661621,patience counter: 10
# Epoch: 23 | average train loss over most recent 25 batches: 67.42879413604736,average val loss over most recent 25 batches: 27.612315406799315,patience counter: 10
# Epoch: 24 | average train loss over most recent 25 batches: 61.960522499084476,average val loss over most recent 25 batches: 26.569874687194826,patience counter: 10
# Epoch: 25 | average train loss over most recent 25 batches: 51.751671867370604,average val loss over most recent 25 batches: 25.02045108795166,patience counter: 10
# Epoch: 26 | average train loss over most recent 25 batches: 42.56908622741699,average val loss over most recent 25 batches: 24.013029327392577,patience counter: 10
# Epoch: 27 | average train loss over most recent 25 batches: 46.89844938278198,average val loss over most recent 25 batches: 22.835481624603272,patience counter: 10
# Epoch: 28 | average train loss over most recent 25 batches: 56.421656455993656,average val loss over most recent 25 batches: 22.25515678405762,patience counter: 10
# Epoch: 29 | average train loss over most recent 25 batches: 55.50142374038696,average val loss over most recent 25 batches: 21.399199504852294,patience counter: 10
# Epoch: 30 | average train loss over most recent 25 batches: 53.8732202911377,average val loss over most recent 25 batches: 20.257770977020265,patience counter: 10
# Epoch: 31 | average train loss over most recent 25 batches: 44.95936332702637,average val loss over most recent 25 batches: 18.751872901916503,patience counter: 10
# Epoch: 32 | average train loss over most recent 25 batches: 55.13155309677124,average val loss over most recent 25 batches: 18.042881546020507,patience counter: 10
# Epoch: 33 | average train loss over most recent 25 batches: 36.12075872421265,average val loss over most recent 25 batches: 17.67759817123413,patience counter: 10
# Epoch: 34 | average train loss over most recent 25 batches: 38.20439710617065,average val loss over most recent 25 batches: 16.755095844268798,patience counter: 10
# Epoch: 35 | average train loss over most recent 25 batches: 36.133209009170535,average val loss over most recent 25 batches: 16.26137418746948,patience counter: 10
# Epoch: 36 | average train loss over most recent 25 batches: 40.90553807258606,average val loss over most recent 25 batches: 15.608507595062257,patience counter: 10
# Epoch: 37 | average train loss over most recent 25 batches: 40.4051668548584,average val loss over most recent 25 batches: 15.179371089935303,patience counter: 10
# Epoch: 38 | average train loss over most recent 25 batches: 34.31642492294311,average val loss over most recent 25 batches: 14.554348068237305,patience counter: 10
# Epoch: 39 | average train loss over most recent 25 batches: 37.582189245224,average val loss over most recent 25 batches: 14.209824028015136,patience counter: 10
# Epoch: 40 | average train loss over most recent 25 batches: 35.22069080352783,average val loss over most recent 25 batches: 13.714163122177125,patience counter: 10
# Epoch: 41 | average train loss over most recent 25 batches: 34.17906593322754,average val loss over most recent 25 batches: 13.631793193817138,patience counter: 10
# Epoch: 42 | average train loss over most recent 25 batches: 37.969112644195555,average val loss over most recent 25 batches: 13.033010654449463,patience counter: 10
# Epoch: 43 | average train loss over most recent 25 batches: 31.798104491233826,average val loss over most recent 25 batches: 12.452719955444335,patience counter: 10
# Epoch: 44 | average train loss over most recent 25 batches: 34.086165771484374,average val loss over most recent 25 batches: 12.083334512710572,patience counter: 10
# Epoch: 45 | average train loss over most recent 25 batches: 27.664145097732543,average val loss over most recent 25 batches: 11.5042475605011,patience counter: 10
# Epoch: 46 | average train loss over most recent 25 batches: 31.82374044418335,average val loss over most recent 25 batches: 11.088360872268677,patience counter: 10
# Epoch: 47 | average train loss over most recent 25 batches: 24.58454586029053,average val loss over most recent 25 batches: 10.746093702316283,patience counter: 10
# Epoch: 48 | average train loss over most recent 25 batches: 25.21029793739319,average val loss over most recent 25 batches: 10.223238544464111,patience counter: 10
# Epoch: 49 | average train loss over most recent 25 batches: 28.719057331085207,average val loss over most recent 25 batches: 10.180021781921386,patience counter: 10
# Epoch: 50 | average train loss over most recent 25 batches: 21.406640243530273,average val loss over most recent 25 batches: 9.840055074691772,patience counter: 10
# Epoch: 51 | average train loss over most recent 25 batches: 25.670397529602052,average val loss over most recent 25 batches: 9.750614900588989,patience counter: 10
# Epoch: 52 | average train loss over most recent 25 batches: 23.599766578674316,average val loss over most recent 25 batches: 9.396298303604127,patience counter: 10
# Epoch: 53 | average train loss over most recent 25 batches: 26.04711079120636,average val loss over most recent 25 batches: 9.200282363891601,patience counter: 10
# Epoch: 54 | average train loss over most recent 25 batches: 23.35806800842285,average val loss over most recent 25 batches: 9.02923014640808,patience counter: 10
# Epoch: 55 | average train loss over most recent 25 batches: 19.829484491348268,average val loss over most recent 25 batches: 8.92254690170288,patience counter: 10
# Epoch: 56 | average train loss over most recent 25 batches: 24.649704241752623,average val loss over most recent 25 batches: 9.122991180419922,patience counter: 9
# Epoch: 57 | average train loss over most recent 25 batches: 22.028227977752685,average val loss over most recent 25 batches: 8.727635116577149,patience counter: 10
# Epoch: 58 | average train loss over most recent 25 batches: 19.505976181030274,average val loss over most recent 25 batches: 8.745040864944459,patience counter: 9
# Epoch: 59 | average train loss over most recent 25 batches: 19.21582755088806,average val loss over most recent 25 batches: 8.672842092514038,patience counter: 10
# Epoch: 60 | average train loss over most recent 25 batches: 25.711387004852295,average val loss over most recent 25 batches: 8.61901279449463,patience counter: 10
# Epoch: 61 | average train loss over most recent 25 batches: 20.72719690322876,average val loss over most recent 25 batches: 8.530672187805175,patience counter: 10
# Epoch: 62 | average train loss over most recent 25 batches: 18.949373874664307,average val loss over most recent 25 batches: 8.319052324295043,patience counter: 10
# Epoch: 63 | average train loss over most recent 25 batches: 22.939351115226746,average val loss over most recent 25 batches: 8.296876039505005,patience counter: 10
# Epoch: 64 | average train loss over most recent 25 batches: 18.789328026771546,average val loss over most recent 25 batches: 8.456783208847046,patience counter: 9
# Epoch: 65 | average train loss over most recent 25 batches: 18.951073665618896,average val loss over most recent 25 batches: 8.285689954757691,patience counter: 10
# Epoch: 66 | average train loss over most recent 25 batches: 25.055905795097352,average val loss over most recent 25 batches: 8.29010347366333,patience counter: 9
# Epoch: 67 | average train loss over most recent 25 batches: 18.030234937667846,average val loss over most recent 25 batches: 8.178761386871338,patience counter: 10
# Epoch: 68 | average train loss over most recent 25 batches: 18.189766299724578,average val loss over most recent 25 batches: 8.096825275421143,patience counter: 10
# Epoch: 69 | average train loss over most recent 25 batches: 21.404048919677734,average val loss over most recent 25 batches: 8.383043994903565,patience counter: 9
# Epoch: 70 | average train loss over most recent 25 batches: 22.797735843658447,average val loss over most recent 25 batches: 8.065690746307373,patience counter: 10
# Epoch: 71 | average train loss over most recent 25 batches: 22.820167956352233,average val loss over most recent 25 batches: 7.872948493957519,patience counter: 10
# Epoch: 72 | average train loss over most recent 25 batches: 15.391103010177613,average val loss over most recent 25 batches: 7.963207759857178,patience counter: 9
# Epoch: 73 | average train loss over most recent 25 batches: 24.853182497024537,average val loss over most recent 25 batches: 8.287091355323792,patience counter: 8
# Epoch: 74 | average train loss over most recent 25 batches: 19.53788510084152,average val loss over most recent 25 batches: 8.371012783050537,patience counter: 7
# Epoch: 75 | average train loss over most recent 25 batches: 21.16692383766174,average val loss over most recent 25 batches: 8.001715173721314,patience counter: 6
# Epoch: 76 | average train loss over most recent 25 batches: 16.235713768005372,average val loss over most recent 25 batches: 8.339651222229003,patience counter: 5
# Epoch 00077: reducing learning rate of group 0 to 2.0000e-04.
# Epoch: 77 | average train loss over most recent 25 batches: 23.658580062389373,average val loss over most recent 25 batches: 8.130303239822387,patience counter: 4
# Epoch: 78 | average train loss over most recent 25 batches: 19.171176710128783,average val loss over most recent 25 batches: 7.803016996383667,patience counter: 10
# Epoch: 79 | average train loss over most recent 25 batches: 19.062389059066774,average val loss over most recent 25 batches: 7.741011295318604,patience counter: 10
# Epoch: 80 | average train loss over most recent 25 batches: 19.41950662612915,average val loss over most recent 25 batches: 7.740175242424011,patience counter: 10
# Epoch: 81 | average train loss over most recent 25 batches: 21.48039895057678,average val loss over most recent 25 batches: 7.747180275917053,patience counter: 9
# Epoch: 82 | average train loss over most recent 25 batches: 21.66419264793396,average val loss over most recent 25 batches: 7.736227865219116,patience counter: 10
# Epoch: 83 | average train loss over most recent 25 batches: 16.38985463142395,average val loss over most recent 25 batches: 7.740827279090881,patience counter: 9
# Epoch: 84 | average train loss over most recent 25 batches: 19.524540996551515,average val loss over most recent 25 batches: 7.666852827072144,patience counter: 10
# Epoch: 85 | average train loss over most recent 25 batches: 20.509008564949035,average val loss over most recent 25 batches: 7.728930492401123,patience counter: 9
# Epoch: 86 | average train loss over most recent 25 batches: 17.186021914482115,average val loss over most recent 25 batches: 7.699761729240418,patience counter: 8
# Epoch: 87 | average train loss over most recent 25 batches: 18.60861825942993,average val loss over most recent 25 batches: 7.710662102699279,patience counter: 7
# Epoch: 88 | average train loss over most recent 25 batches: 22.479372358322145,average val loss over most recent 25 batches: 7.66367121219635,patience counter: 10
# Epoch: 89 | average train loss over most recent 25 batches: 17.2064186668396,average val loss over most recent 25 batches: 7.698033857345581,patience counter: 9
# Epoch: 90 | average train loss over most recent 25 batches: 17.828303461074828,average val loss over most recent 25 batches: 7.68003659248352,patience counter: 8
# Epoch: 91 | average train loss over most recent 25 batches: 17.60879159450531,average val loss over most recent 25 batches: 7.641297869682312,patience counter: 10
# Epoch: 92 | average train loss over most recent 25 batches: 16.509368851184846,average val loss over most recent 25 batches: 7.712287673950195,patience counter: 9
# Epoch: 93 | average train loss over most recent 25 batches: 14.972230768203735,average val loss over most recent 25 batches: 7.616492490768433,patience counter: 10
# Epoch: 94 | average train loss over most recent 25 batches: 15.155327262878417,average val loss over most recent 25 batches: 7.645570759773254,patience counter: 9
# Epoch: 95 | average train loss over most recent 25 batches: 20.052684416770933,average val loss over most recent 25 batches: 7.638312683105469,patience counter: 8
# Epoch: 96 | average train loss over most recent 25 batches: 19.7359375667572,average val loss over most recent 25 batches: 7.630747199058533,patience counter: 7
# Epoch: 97 | average train loss over most recent 25 batches: 19.274393959045412,average val loss over most recent 25 batches: 7.613634357452392,patience counter: 10
# Epoch: 98 | average train loss over most recent 25 batches: 17.636339299678802,average val loss over most recent 25 batches: 7.592188425064087,patience counter: 10
# Epoch: 99 | average train loss over most recent 25 batches: 24.65455041885376,average val loss over most recent 25 batches: 7.60502091884613,patience counter: 9
# Epoch: 100 | average train loss over most recent 25 batches: 17.981368989944457,average val loss over most recent 25 batches: 7.614222083091736,patience counter: 8

# %%
# Save model
save_model(best_model, 'DNN_AE_V11')

# %%
# Load model
dense_AE = DNN_AE(input_dim=INPUT_DIM, hidden_dim=HIDDEN_DIM, latent_dim=LATENT_DIM)
dense_AE = load_model(dense_AE, 'DNN_AE_V11')
trainer = Trainer(model=dense_AE, num_batches_avg=25,
                  loss_fn=loss_fn, optimizer=optimizer, scheduler=scheduler)

# %% [markdown]
# ## Prediction

# %%
bkg_prediction = trainer.predict_step(dataloader=test_loader)

# %%
# add correct signal labels
signal_labels = ['Ato4l', 'hChToTauNu', 'hToTauTau', 'leptoquark']

# %%
# add correct path to signal files
drive_path = '/content/gdrive/MyDrive/Penn/Colab/Data/'
signals_file = [drive_path+label+'_dataset.h5' for label in signal_labels]
print(signals_file)
# Out:
# ['/content/gdrive/MyDrive/Penn/Colab/Data/Ato4l_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/hChToTauNu_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/hToTauTau_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/leptoquark_dataset.h5']

# %%
# read signal data
signal_data = []
for i, label in enumerate(signal_labels):
    with h5py.File(signals_file[i], 'r') as file:
        test_data = np.array(file[label])
    signal_data.append(test_data)

print(np.array(signal_data).shape)
# Out:
# (4,)
# <ipython-input-200-fcddd4288aef>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(np.array(signal_data).shape)

# %%
signal_results = []

for i, label in enumerate(signal_labels):
    signal_prediction = dense_AE(torch.tensor(signal_data[i], requires_grad=False).float())
    signal_results.append([label, signal_data[i], signal_prediction]) # save [label, true, prediction] for signal

# %%
def AD_score(y, x):
    # masked mse
    mask = (y != 0)
    _x = x * mask
    _y = y * mask
    return (mse_loss(_y, _x))

# %%
# compute loss value (true, predicted)
total_loss = []
total_loss.append(AD_score(X_test,
                           bkg_prediction.astype(np.float32)))
for i, signal_X in enumerate(signal_data):
    total_loss.append(AD_score(signal_X,
                               signal_results[i][2].detach().numpy().astype(np.float32)))

# %%
bin_size=100
labels = np.concatenate([['Background'], np.array(signal_labels)])
plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    plt.hist(total_loss[i], bins=bin_size, label=label, density = True, histtype='step', fill=False, linewidth=1.5)

plt.yscale('log')
plt.xlabel("Autoencoder Loss")
plt.ylabel("Probability (a.u.)")
plt.title('MSE loss')
plt.legend(loc='best')
plt.show()

# %%
target_background = np.zeros(total_loss[0].shape[0])

plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    if i == 0: continue # background events

    trueVal = np.concatenate((np.ones(total_loss[i].shape[0]), target_background)) # anomaly=1, bkg=0
    predVal_loss = np.concatenate((total_loss[i], total_loss[0]))

    fpr_loss, tpr_loss, threshold_loss = roc_curve(trueVal, predVal_loss)

    auc_loss = auc(fpr_loss, tpr_loss)

    plt.plot(fpr_loss, tpr_loss, "-", label='%s (auc = %.1f%%)'%(label,auc_loss*100.), linewidth=1.5)

    plt.semilogx()
    plt.semilogy()
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    plt.legend(loc='center right')
    plt.grid(True)
    plt.tight_layout()
plt.plot(np.linspace(0, 1),np.linspace(0, 1), '--', color='0.75')
plt.axvline(0.00001, color='red', linestyle='dashed', linewidth=1) # threshold value for measuring anomaly detection efficiency
plt.title("ROC AE")
plt.show()

# %% [markdown]
# ## Evaluation

# %%
# Calculate the threshold for a give rejection rate using the background datset

REJECTION_RATE = pow(10, 4)


# Calculate fpr, tpr, thresholds
trueVal = target_background
predVal_loss = np.array(total_loss[0])
fpr_loss, tpr_loss, threshold_loss = roc_curve(trueVal, predVal_loss, drop_intermediate=False)

# Loop over thresholds
for i, thresh in enumerate(threshold_loss):
    preds = (predVal_loss >= thresh)
    rejection_rate = (len(preds) - np.sum(preds)) / np.sum(preds) # number of background / number of anomaly

    # Breaking
    if rejection_rate < REJECTION_RATE:
        break

    threshold = thresh # update threshold

pred_test = (predVal_loss >= threshold)
print(f'\nrejection rate = {(len(pred_test) - np.sum(pred_test)) / np.sum(pred_test):.2f}')
print(f'threshold = {threshold:.2f}\n\n')
# Out:
# rejection rate = 10525.32
# threshold = 474.73
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# <ipython-input-206-ef13861a7d00>:14: RuntimeWarning: divide by zero encountered in long_scalars
#   rejection_rate = (len(preds) - np.sum(preds)) / np.sum(preds) # number of background / number of anomaly

# %%
# Calcalate the TPR and efficiency of each signal dataset


display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 20000})''')) # No scroll bar

# Loop over signal datasets
for i, label in enumerate(labels):
    if i ==0: continue # background

    # Calculate TPR
    trueVal = np.concatenate((np.ones(total_loss[i].shape[0]), target_background)) # anomaly=1, bkg=0
    true_indices = np.nonzero(trueVal)[0] # true anomaly indices
    predVal = 1 * (np.concatenate((total_loss[i], total_loss[0])) >= threshold) # 1=anomaly, 0=bkg
    pred_indices = np.nonzero(predVal)[0] # indices of anomaly prediction
    TP = len(np.intersect1d(pred_indices, true_indices)) # the number of elements shared between trueVal and predVal
    TPR = TP / np.sum(trueVal)

    # Printing
    print(f'\n{label}:')
    print(f'length of dataset: {total_loss[i].shape[0]}')
    print(f'TP = {TP}')
    print(f'TPR = {TPR:.4f}\n')

    # Get pT from data
    X = np.concatenate((signal_data[i-1], X_test)).reshape(-1, 19, 3, 1) # Data beore going through model
    pT = X[:, 1:, 0, 0]
    pT_max = np.max(pT, axis=1) # Maximum pT in each event
    pT_sum = np.sum(pT, axis=1) # Sum of the pT in each event

    # Make histograms
    pT_hist_A, edges_A = np.histogram(pT_sum, bins=20) # all events
    pT_hist_B, edges_B = np.histogram(pT_sum[pred_indices], bins=20, range=(pT_sum.min(), pT_sum.max())) # only events predicted as anomalous
    bin_centers = edges_A[0:-1] + ((edges_A[1] - edges_A[0])/2)


    # Plot Histograms
    plt.figure(figsize=(10, 5))
    plt.rcParams['axes.linewidth'] = 2.4
    plt.grid(zorder=0)
    plt.title(f'{label} pT Histogram', fontsize=20)
    plt.xlabel('Total pT in Event', fontsize=15)
    plt.ylabel('Frequency', fontsize=15)
    plt.bar(bin_centers, pT_hist_A, width=(edges_A[1] - edges_A[0]), color='mediumvioletred', edgecolor='k', linewidth=3, zorder=2, label='All Events')
    plt.bar(bin_centers, pT_hist_B, width=(edges_A[1] - edges_A[0]), color='k', zorder=3, label='Anomaly Events', alpha=0.75)
    plt.yscale('log')
    plt.legend(fontsize=13)
    plt.show()
    print('')

    # Plot Efficiency
    plt.figure(figsize=(10, 5))
    plt.rcParams['axes.linewidth'] = 2.4
    plt.grid(zorder=0)
    plt.title(f'{label} pT Efficiency', fontsize=20)
    plt.xlabel('Total pT in Event', fontsize=15)
    plt.ylabel('Efficiency', fontsize=15)
    plt.bar(bin_centers, pT_hist_B/pT_hist_A, width=(edges_A[1] - edges_A[0]), color='mediumvioletred', edgecolor='k', linewidth=2.5, zorder=2)
    plt.show()
    print('_________________________________________________________________________________________________')
# Out:
# Ato4l:
# length of dataset: 55969
# TP = 272
# TPR = 0.0049
# <ipython-input-207-37caf4cd36cb>:57: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(bin_centers, pT_hist_B/pT_hist_A, width=(edges_A[1] - edges_A[0]), color='mediumvioletred', edgecolor='k', linewidth=2.5, zorder=2)
# _________________________________________________________________________________________________
#
# hChToTauNu:
# length of dataset: 760272
# TP = 6105
# TPR = 0.0080
# _________________________________________________________________________________________________
#
# hToTauTau:
# length of dataset: 691283
# TP = 1490
# TPR = 0.0022
# _________________________________________________________________________________________________
#
# leptoquark:
# length of dataset: 340544
# TP = 147
# TPR = 0.0004
# _________________________________________________________________________________________________

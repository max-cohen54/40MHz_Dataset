# %%
import numpy as np
import h5py
import math
import os
import pathlib
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import torch
import random
import torch.nn as nn
import sklearn
import collections
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
import json
from torch.optim import Adam
import pylab
from scipy.optimize import curve_fit
from google.colab import drive
drive.mount('/content/gdrive')
import sys
sys.path.insert(0,'/content/gdrive/MyDrive/Penn/Colab/Data/')
from functions import load_model, save_model, Dataset, mse_loss
from sklearn.metrics import roc_curve, auc
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load Background data, which will be used for training
filename = 'BKG_dataset.h5'
with h5py.File('/content/gdrive/MyDrive/Penn/Colab/Data/BKG_dataset.h5', 'r') as file:
    X_train = np.array(file['X_train'])
    X_test = np.array(file['X_test'])
    X_val = np.array(file['X_val'])

print(X_train.shape)
# Out:
# (640000, 57)

# %%
# Define consts
LEARNING_RATE = 1e-3
PATIENCE = 10
NUM_EPOCHS = 100
BATCH_SIZE = 1024

# %%
# Initialize datasets
train_dataset = Dataset(X=X_train, y=X_train)
test_dataset = Dataset(X=X_test, y=X_test)
val_dataset = Dataset(X=X_val, y=X_val)

# %%
# Initialize dataloaders
train_loader = train_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=True)
test_loader = test_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=False)
val_loader = val_dataset.create_dataloader(batch_size=BATCH_SIZE, shuffle=False)
batch_X, batch_y = next(iter(train_loader))
print ("Sample batch:\n"
    f"  X: {list(batch_X.size())}\n"
    f"  y: {list(batch_y.size())}\n")
# Out:
# Sample batch:
#   X: [1024, 57]
#   y: [1024, 57]
# /content/gdrive/MyDrive/Penn/Colab/Data/functions.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = [torch.tensor(sample[0]).float() for sample in batch]
# /content/gdrive/MyDrive/Penn/Colab/Data/functions.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = [torch.tensor(sample[1]).float() for sample in batch]

# %%
class DNN_VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        """input_dim: dimension of the input data.
        latent_dim: dimension of the latent space. Should be smaller than all of the other layers.
        num_nodes: two element array containing the number of nodes in the two hidden layers."""
        super(DNN_VAE, self).__init__()

        # Encoder layers
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc_logvar = nn.Linear(hidden_dim, latent_dim)

        # Decoder layers
        self.fc2 = nn.Linear(latent_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, input_dim)

    def forward(self, x_in):
        """Forward through the autoencoder with relu activation."""

        # Encoder
        h = F.relu(self.fc1(x_in))
        mean = self.fc_mean(h)
        logvar = self.fc_logvar(h)

        # reparameterize
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        z = mean + eps*std

        # Decoder
        h = F.relu(self.fc2(z))
        z = self.fc3(h)
        return z, mean, logvar

    def loss_function(self, x, y, mu, logvar, beta=0.42):
        """Compute the VAE loss. Beta was calculated to be roughly 0.4 for equal
        contribution of mse and kl loss terms."""
        # Reconstruction loss (MSE)
        recon_loss = F.mse_loss(x, y, reduction='mean')

        # KL divergence loss
        kl_loss = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

        # Total loss
        loss = (1 - beta)*recon_loss + beta*kl_loss
        return loss

# %%
# Define a class which will handle training and testing the model
class Trainer(object):
    def __init__(self, model, num_batches_avg, loss_fn=None, optimizer=None, scheduler=None):
        """num_batches_avg: Number of batches to calculate the average loss over.
        example: if there are 625 batches, we might want to use 25, to calculate
        average loss over 25 batches."""

        #Set params
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.num_batches_avg = num_batches_avg

    def train_step(self, dataloader):
        """Train for one epoch.

        returns: average loss over most recent {num_batches_avg} batches, loss over most recent batch
        """

        self.model.train()
        current_loss = 0.0 # Average loss of most recent batch
        avg_loss = 0.0 # Average loss over a certain number of batches
        running_loss = 0.0

        # Iterate over batches in dataloader
        for i, batch in enumerate(dataloader):

            # Pass a single batch through the model and update the weights
            inputs, targets = batch
            self.optimizer.zero_grad()
            outputs, mu, logvar = self.model(inputs)
            loss = self.loss_fn(outputs, targets, mu, logvar)
            loss.backward()
            #torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
            self.optimizer.step()

            # Update loss metrics
            running_loss += loss.item()
            current_loss = loss.item()

            # Calculate the average loss
            if i % self.num_batches_avg == self.num_batches_avg - 1:
                avg_loss = running_loss / self.num_batches_avg
                running_loss = 0.0

        return avg_loss, current_loss

    def eval_step(self, dataloader):
        """validation or test step over one epoch."""

        self.model.eval()
        current_loss = 0.0 # Average loss of most recent batch
        avg_loss = 0.0 # Average loss over a certain number of batches
        running_loss = 0.0
        y_trues, model_outputs = [], []

        # Iterate over val batches
        with torch.no_grad():
            for i, batch in enumerate(dataloader):

                # Pass a single batch through the model
                inputs, y_true = batch
                outputs, mu, logvar = self.model(inputs)
                loss = self.loss_fn(outputs, y_true, mu, logvar)

                # Update loss metrics
                running_loss += loss.item()
                current_loss = loss.item()

                # Calculate the average loss
                if i % self.num_batches_avg == self.num_batches_avg - 1:
                    avg_loss = running_loss / self.num_batches_avg
                    running_loss = 0.0

                # Store outputs
                y_trues.extend(y_true)
                model_outputs.extend(outputs)
        return avg_loss, current_loss, np.vstack(y_trues), np.vstack(model_outputs)

    def predict_step(self, dataloader):
        """Prediction step."""
        self.model.eval()
        model_outputs = []

        # Iterate over batches
        with torch.no_grad():
            for i, batch in enumerate(dataloader):

                # Pass a single batch through the model
                inputs, targets = batch
                outputs, mu , logvar = self.model(inputs)

                # Store outputs
                model_outputs.extend(outputs)

        return np.vstack(model_outputs), np.vstack(mu), np.vstack(logvar)

    def train(self, num_epochs, patience, train_dataloader, val_dataloader):
        """Train the neural net."""

        best_val_loss = np.inf
        patience_counter=patience

        # Loop over epochs
        for epoch in range(num_epochs):

            # Steps
            avg_train_loss, last_train_loss = self.train_step(dataloader=train_dataloader)
            avg_val_loss, last_val_loss, _, _ = self.eval_step(dataloader=val_dataloader)
            self.scheduler.step(avg_val_loss)

            # Early stopping
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = self.model
                patience_counter = patience # reset patience
            else:
                patience_counter -= 1
            if not patience_counter: # 0
                print("Stoping Early!")
                break

            # Logging
            print(f'Epoch: {epoch+1} | '
            f'average train loss over most recent {self.num_batches_avg} batches: {avg_train_loss},'
            f'average val loss over most recent {self.num_batches_avg} batches: {avg_val_loss},'
            #f'learning rate: {self.optimizer.param_groups[0]['lr']:.2E},'
            f'patience counter: {patience_counter}')

        return best_model

# %%
# Initialize model
INPUT_DIM = X_train.shape[1]
HIDDEN_DIM = 16
LATENT_DIM = 3
dense_VAE = DNN_VAE(input_dim=INPUT_DIM, hidden_dim=HIDDEN_DIM, latent_dim=LATENT_DIM)
print(dense_VAE.named_parameters)
# Out:
# <bound method Module.named_parameters of DNN_VAE(
#   (fc1): Linear(in_features=57, out_features=16, bias=True)
#   (fc_mean): Linear(in_features=16, out_features=3, bias=True)
#   (fc_logvar): Linear(in_features=16, out_features=3, bias=True)
#   (fc2): Linear(in_features=3, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=57, bias=True)
# )>

# %%
# Calculate the appropriate beta value for loss function
# (We want the mse and kl loss terms to be roughly equal contributions)

outputs, mu, logvar = dense_VAE(batch_X)
_mse_loss = F.mse_loss(outputs, batch_X, reduction='mean')
kl_loss = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())
beta = _mse_loss / (kl_loss + _mse_loss)
print(f'mse loss: {_mse_loss}')
print(f'kl loss: {kl_loss}')
print(f'beta: {beta}')
# Out:
# mse loss: 107.0024642944336
# kl loss: 1.6158772706985474
# beta: 0.9851233959197998

# %%
# Initialize the loss function, optimizer and lr scheduler, trainer
def loss_fn(x_in, y, mu, logvar):
    return dense_VAE.loss_function(x_in, y, mu, logvar)
optimizer = Adam(params=dense_VAE.parameters(), lr=LEARNING_RATE)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.2, patience=5, verbose=True)
trainer = Trainer(model=dense_VAE, num_batches_avg=25,
                  loss_fn=loss_fn, optimizer=optimizer, scheduler=scheduler)

# %%
# Train
best_model = trainer.train(
    num_epochs=NUM_EPOCHS, patience=PATIENCE,
    train_dataloader=train_loader, val_dataloader=val_loader)
# Out:
# Epoch: 1 | average train loss over most recent 25 batches: 13.250099220275878,average val loss over most recent 25 batches: 13.307028083801269,patience counter: 10
# Epoch: 2 | average train loss over most recent 25 batches: 5.3228864669799805,average val loss over most recent 25 batches: 5.585475730895996,patience counter: 10
# Epoch: 3 | average train loss over most recent 25 batches: 4.4163209819793705,average val loss over most recent 25 batches: 4.513451061248779,patience counter: 10
# Epoch: 4 | average train loss over most recent 25 batches: 3.820646047592163,average val loss over most recent 25 batches: 3.8998895645141602,patience counter: 10
# Epoch: 5 | average train loss over most recent 25 batches: 3.4583843517303468,average val loss over most recent 25 batches: 3.455760326385498,patience counter: 10
# Epoch: 6 | average train loss over most recent 25 batches: 3.054696378707886,average val loss over most recent 25 batches: 3.079624309539795,patience counter: 10
# Epoch: 7 | average train loss over most recent 25 batches: 2.763652830123901,average val loss over most recent 25 batches: 2.7879758739471434,patience counter: 10
# Epoch: 8 | average train loss over most recent 25 batches: 2.5980114459991457,average val loss over most recent 25 batches: 2.627757501602173,patience counter: 10
# Epoch: 9 | average train loss over most recent 25 batches: 2.5606664180755616,average val loss over most recent 25 batches: 2.5305683612823486,patience counter: 10
# Epoch: 10 | average train loss over most recent 25 batches: 2.5213506412506104,average val loss over most recent 25 batches: 2.469539079666138,patience counter: 10
# Epoch: 11 | average train loss over most recent 25 batches: 2.5369177722930907,average val loss over most recent 25 batches: 2.4288333225250245,patience counter: 10
# Epoch: 12 | average train loss over most recent 25 batches: 2.485007438659668,average val loss over most recent 25 batches: 2.389782314300537,patience counter: 10
# Epoch: 13 | average train loss over most recent 25 batches: 2.35864727973938,average val loss over most recent 25 batches: 2.351469349861145,patience counter: 10
# Epoch: 14 | average train loss over most recent 25 batches: 2.332692060470581,average val loss over most recent 25 batches: 2.328895535469055,patience counter: 10
# Epoch: 15 | average train loss over most recent 25 batches: 2.292782759666443,average val loss over most recent 25 batches: 2.3137005043029784,patience counter: 10
# Epoch: 16 | average train loss over most recent 25 batches: 2.227941884994507,average val loss over most recent 25 batches: 2.29922164440155,patience counter: 10
# Epoch: 17 | average train loss over most recent 25 batches: 2.2684609508514404,average val loss over most recent 25 batches: 2.2828553676605225,patience counter: 10
# Epoch: 18 | average train loss over most recent 25 batches: 2.157521162033081,average val loss over most recent 25 batches: 2.26185564994812,patience counter: 10
# Epoch: 19 | average train loss over most recent 25 batches: 2.276767292022705,average val loss over most recent 25 batches: 2.2515690088272096,patience counter: 10
# Epoch: 20 | average train loss over most recent 25 batches: 2.2486431884765623,average val loss over most recent 25 batches: 2.2308539533615113,patience counter: 10
# Epoch: 21 | average train loss over most recent 25 batches: 2.270673952102661,average val loss over most recent 25 batches: 2.23615581035614,patience counter: 9
# Epoch: 22 | average train loss over most recent 25 batches: 2.267410283088684,average val loss over most recent 25 batches: 2.2154028463363646,patience counter: 10
# Epoch: 23 | average train loss over most recent 25 batches: 2.191195502281189,average val loss over most recent 25 batches: 2.206636881828308,patience counter: 10
# Epoch: 24 | average train loss over most recent 25 batches: 2.2500271606445312,average val loss over most recent 25 batches: 2.2083385181427,patience counter: 9
# Epoch: 25 | average train loss over most recent 25 batches: 2.2268618822097777,average val loss over most recent 25 batches: 2.1974212741851806,patience counter: 10
# Epoch: 26 | average train loss over most recent 25 batches: 2.2301446294784544,average val loss over most recent 25 batches: 2.18647066116333,patience counter: 10
# Epoch: 27 | average train loss over most recent 25 batches: 2.2176711654663084,average val loss over most recent 25 batches: 2.1842667198181154,patience counter: 10
# Epoch: 28 | average train loss over most recent 25 batches: 2.1361880779266356,average val loss over most recent 25 batches: 2.18070809841156,patience counter: 10
# Epoch: 29 | average train loss over most recent 25 batches: 2.217973761558533,average val loss over most recent 25 batches: 2.1886262607574465,patience counter: 9
# Epoch: 30 | average train loss over most recent 25 batches: 2.233913402557373,average val loss over most recent 25 batches: 2.1973163175582884,patience counter: 8
# Epoch: 31 | average train loss over most recent 25 batches: 2.198117980957031,average val loss over most recent 25 batches: 2.1701234197616577,patience counter: 10
# Epoch: 32 | average train loss over most recent 25 batches: 2.166989636421204,average val loss over most recent 25 batches: 2.1584684371948244,patience counter: 10
# Epoch: 33 | average train loss over most recent 25 batches: 2.144145121574402,average val loss over most recent 25 batches: 2.156617298126221,patience counter: 10
# Epoch: 34 | average train loss over most recent 25 batches: 2.1445311975479124,average val loss over most recent 25 batches: 2.153462977409363,patience counter: 10
# Epoch: 35 | average train loss over most recent 25 batches: 2.113292579650879,average val loss over most recent 25 batches: 2.1524517488479615,patience counter: 10
# Epoch: 36 | average train loss over most recent 25 batches: 2.0581051445007326,average val loss over most recent 25 batches: 2.14557891368866,patience counter: 10
# Epoch: 37 | average train loss over most recent 25 batches: 2.2437177515029907,average val loss over most recent 25 batches: 2.1542182636260985,patience counter: 9
# Epoch: 38 | average train loss over most recent 25 batches: 2.1815203475952147,average val loss over most recent 25 batches: 2.1457381725311278,patience counter: 8
# Epoch: 39 | average train loss over most recent 25 batches: 2.17247154712677,average val loss over most recent 25 batches: 2.1363529777526855,patience counter: 10
# Epoch: 40 | average train loss over most recent 25 batches: 2.0466018533706665,average val loss over most recent 25 batches: 2.1208700275421144,patience counter: 10
# Epoch: 41 | average train loss over most recent 25 batches: 2.140274472236633,average val loss over most recent 25 batches: 2.122572174072266,patience counter: 9
# Epoch: 42 | average train loss over most recent 25 batches: 2.125535559654236,average val loss over most recent 25 batches: 2.1187534523010254,patience counter: 10
# Epoch: 43 | average train loss over most recent 25 batches: 2.142951974868774,average val loss over most recent 25 batches: 2.10991539478302,patience counter: 10
# Epoch: 44 | average train loss over most recent 25 batches: 2.087903437614441,average val loss over most recent 25 batches: 2.1097850513458254,patience counter: 10
# Epoch: 45 | average train loss over most recent 25 batches: 2.1418880128860476,average val loss over most recent 25 batches: 2.1138845539093016,patience counter: 9
# Epoch: 46 | average train loss over most recent 25 batches: 2.113813486099243,average val loss over most recent 25 batches: 2.0990818452835085,patience counter: 10
# Epoch: 47 | average train loss over most recent 25 batches: 2.0578196811676026,average val loss over most recent 25 batches: 2.100062074661255,patience counter: 9
# Epoch: 48 | average train loss over most recent 25 batches: 2.2996303272247314,average val loss over most recent 25 batches: 2.1031035661697386,patience counter: 8
# Epoch: 49 | average train loss over most recent 25 batches: 2.142439742088318,average val loss over most recent 25 batches: 2.095307860374451,patience counter: 10
# Epoch: 50 | average train loss over most recent 25 batches: 2.2152329444885255,average val loss over most recent 25 batches: 2.080750608444214,patience counter: 10
# Epoch: 51 | average train loss over most recent 25 batches: 2.1054203701019287,average val loss over most recent 25 batches: 2.082911005020142,patience counter: 9
# Epoch: 52 | average train loss over most recent 25 batches: 2.0632573413848876,average val loss over most recent 25 batches: 2.0822643089294433,patience counter: 8
# Epoch: 53 | average train loss over most recent 25 batches: 2.1147879552841187,average val loss over most recent 25 batches: 2.0812710618972776,patience counter: 7
# Epoch: 54 | average train loss over most recent 25 batches: 2.148149356842041,average val loss over most recent 25 batches: 2.119224510192871,patience counter: 6
# Epoch: 55 | average train loss over most recent 25 batches: 2.0525767517089846,average val loss over most recent 25 batches: 2.0776035976409912,patience counter: 10
# Epoch: 56 | average train loss over most recent 25 batches: 2.103651180267334,average val loss over most recent 25 batches: 2.0694304800033567,patience counter: 10
# Epoch: 57 | average train loss over most recent 25 batches: 2.1391644859313965,average val loss over most recent 25 batches: 2.063167576789856,patience counter: 10
# Epoch: 58 | average train loss over most recent 25 batches: 2.093059763908386,average val loss over most recent 25 batches: 2.062346034049988,patience counter: 10
# Epoch: 59 | average train loss over most recent 25 batches: 2.098233742713928,average val loss over most recent 25 batches: 2.0559512424468993,patience counter: 10
# Epoch: 60 | average train loss over most recent 25 batches: 2.078216896057129,average val loss over most recent 25 batches: 2.053347043991089,patience counter: 10
# Epoch: 61 | average train loss over most recent 25 batches: 2.01094762802124,average val loss over most recent 25 batches: 2.0511511325836183,patience counter: 10
# Epoch: 62 | average train loss over most recent 25 batches: 1.9891106796264648,average val loss over most recent 25 batches: 2.046866798400879,patience counter: 10
# Epoch: 63 | average train loss over most recent 25 batches: 2.07885507106781,average val loss over most recent 25 batches: 2.042898645401001,patience counter: 10
# Epoch: 64 | average train loss over most recent 25 batches: 2.0339091539382936,average val loss over most recent 25 batches: 2.0446774673461916,patience counter: 9
# Epoch: 65 | average train loss over most recent 25 batches: 2.072178015708923,average val loss over most recent 25 batches: 2.045030965805054,patience counter: 8
# Epoch: 66 | average train loss over most recent 25 batches: 2.0427294921875,average val loss over most recent 25 batches: 2.1227556896209716,patience counter: 7
# Epoch: 67 | average train loss over most recent 25 batches: 2.1105870246887206,average val loss over most recent 25 batches: 2.095920834541321,patience counter: 6
# Epoch: 68 | average train loss over most recent 25 batches: 2.0326023960113524,average val loss over most recent 25 batches: 2.054127745628357,patience counter: 5
# Epoch 00069: reducing learning rate of group 0 to 2.0000e-04.
# Epoch: 69 | average train loss over most recent 25 batches: 2.0691067600250244,average val loss over most recent 25 batches: 2.0505464696884155,patience counter: 4
# Epoch: 70 | average train loss over most recent 25 batches: 2.070808606147766,average val loss over most recent 25 batches: 2.0454084205627443,patience counter: 3
# Epoch: 71 | average train loss over most recent 25 batches: 2.1063616180419924,average val loss over most recent 25 batches: 2.0404992866516114,patience counter: 10
# Epoch: 72 | average train loss over most recent 25 batches: 2.0138095808029175,average val loss over most recent 25 batches: 2.0363710355758666,patience counter: 10
# Epoch: 73 | average train loss over most recent 25 batches: 2.0156767082214357,average val loss over most recent 25 batches: 2.0402716255187987,patience counter: 9
# Epoch: 74 | average train loss over most recent 25 batches: 1.9896099805831908,average val loss over most recent 25 batches: 2.0382205390930177,patience counter: 8
# Epoch: 75 | average train loss over most recent 25 batches: 2.0241801261901857,average val loss over most recent 25 batches: 2.034506850242615,patience counter: 10
# Epoch: 76 | average train loss over most recent 25 batches: 1.9557591485977173,average val loss over most recent 25 batches: 2.0290830993652342,patience counter: 10
# Epoch: 77 | average train loss over most recent 25 batches: 2.1475076913833617,average val loss over most recent 25 batches: 2.030853729248047,patience counter: 9
# Epoch: 78 | average train loss over most recent 25 batches: 2.1873681259155275,average val loss over most recent 25 batches: 2.028916358947754,patience counter: 10
# Epoch: 79 | average train loss over most recent 25 batches: 2.0494497489929198,average val loss over most recent 25 batches: 2.0262602949142456,patience counter: 10
# Epoch: 80 | average train loss over most recent 25 batches: 2.1633241891860964,average val loss over most recent 25 batches: 2.0317103385925295,patience counter: 9
# Epoch: 81 | average train loss over most recent 25 batches: 2.1281192684173584,average val loss over most recent 25 batches: 2.02746120929718,patience counter: 8
# Epoch: 82 | average train loss over most recent 25 batches: 2.1045927476882933,average val loss over most recent 25 batches: 2.0215439081192015,patience counter: 10
# Epoch: 83 | average train loss over most recent 25 batches: 2.0135070753097533,average val loss over most recent 25 batches: 2.019261884689331,patience counter: 10
# Epoch: 84 | average train loss over most recent 25 batches: 1.9794327449798583,average val loss over most recent 25 batches: 2.0181093502044676,patience counter: 10
# Epoch: 85 | average train loss over most recent 25 batches: 1.962359104156494,average val loss over most recent 25 batches: 2.0141800928115843,patience counter: 10
# Epoch: 86 | average train loss over most recent 25 batches: 2.0527934932708742,average val loss over most recent 25 batches: 2.0161543893814087,patience counter: 9
# Epoch: 87 | average train loss over most recent 25 batches: 2.0243043231964113,average val loss over most recent 25 batches: 2.0165440464019775,patience counter: 8
# Epoch: 88 | average train loss over most recent 25 batches: 2.009015965461731,average val loss over most recent 25 batches: 2.0124450016021727,patience counter: 10
# Epoch: 89 | average train loss over most recent 25 batches: 1.9290058135986328,average val loss over most recent 25 batches: 2.010627045631409,patience counter: 10
# Epoch: 90 | average train loss over most recent 25 batches: 2.0176519346237183,average val loss over most recent 25 batches: 2.0124154901504516,patience counter: 9
# Epoch: 91 | average train loss over most recent 25 batches: 2.1673344802856445,average val loss over most recent 25 batches: 2.0177438163757326,patience counter: 8
# Epoch: 92 | average train loss over most recent 25 batches: 2.0270286417007446,average val loss over most recent 25 batches: 2.0124862813949584,patience counter: 7
# Epoch: 93 | average train loss over most recent 25 batches: 1.9448644065856933,average val loss over most recent 25 batches: 2.0072265625,patience counter: 10
# Epoch: 94 | average train loss over most recent 25 batches: 2.0641303777694704,average val loss over most recent 25 batches: 2.00694308757782,patience counter: 10
# Epoch: 95 | average train loss over most recent 25 batches: 1.9719896125793457,average val loss over most recent 25 batches: 2.0057524919509886,patience counter: 10
# Epoch: 96 | average train loss over most recent 25 batches: 2.0387035751342775,average val loss over most recent 25 batches: 2.0062544441223142,patience counter: 9
# Epoch: 97 | average train loss over most recent 25 batches: 1.9870815420150756,average val loss over most recent 25 batches: 2.0054262018203737,patience counter: 10
# Epoch: 98 | average train loss over most recent 25 batches: 1.9908858919143677,average val loss over most recent 25 batches: 2.001019711494446,patience counter: 10
# Epoch: 99 | average train loss over most recent 25 batches: 2.1198136758804322,average val loss over most recent 25 batches: 2.007203302383423,patience counter: 9
# Epoch: 100 | average train loss over most recent 25 batches: 2.0260995864868163,average val loss over most recent 25 batches: 2.0043705892562866,patience counter: 8

# %%
# Save model
save_model(best_model, 'DNN_VAE_3')

# %%
# Load model
dense_VAE = DNN_VAE(input_dim=INPUT_DIM, hidden_dim=HIDDEN_DIM, latent_dim=LATENT_DIM)
dense_VAE = load_model(dense_VAE, 'DNN_VAE_3')
trainer = Trainer(model=dense_VAE, num_batches_avg=25,
                  loss_fn=loss_fn, optimizer=optimizer, scheduler=scheduler)

# %%
# Calculate the appropriate beta value for loss function
# (We want the mse and kl loss terms to be roughly equal contributions)

outputs, mu, logvar = dense_VAE(batch_X)
_mse_loss = F.mse_loss(outputs, batch_X, reduction='mean')
kl_loss = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())
beta = _mse_loss / (kl_loss + _mse_loss)
print(f'mse loss: {_mse_loss}')
print(f'kl loss: {kl_loss}')
print(f'beta: {beta}')
# Out:
# mse loss: 3.239771842956543
# kl loss: 2.2500813007354736
# beta: 0.5901381969451904

# %%
#bkg_prediction, bkg_mu, bkg_logvar = trainer.predict_step(dataloader=test_loader)
bkg_prediction, bkg_mu, bkg_logvar = dense_VAE(torch.tensor(X_test, requires_grad=False).float())
bkg_prediction = bkg_prediction.detach().numpy()

# %%
# add correct signal labels
signal_labels = ['Ato4l', 'hChToTauNu', 'hToTauTau', 'leptoquark']

# %%
# add correct path to signal files
drive_path = '/content/gdrive/MyDrive/Penn/Colab/Data/'
signals_file = [drive_path+label+'_dataset.h5' for label in signal_labels]
print(signals_file)
# Out:
# ['/content/gdrive/MyDrive/Penn/Colab/Data/Ato4l_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/hChToTauNu_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/hToTauTau_dataset.h5', '/content/gdrive/MyDrive/Penn/Colab/Data/leptoquark_dataset.h5']

# %%
# read signal data
signal_data = []
for i, label in enumerate(signal_labels):
    with h5py.File(signals_file[i], 'r') as file:
        test_data = np.array(file[label])
    signal_data.append(test_data)

print(np.array(signal_data).shape)
# Out:
# (4,)
# <ipython-input-16-fcddd4288aef>:8: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   print(np.array(signal_data).shape)

# %%
signal_results = []
sig_mu = []
sig_logvar = []

for i, label in enumerate(signal_labels):
    signal_prediction, mu, logvar = dense_VAE(torch.tensor(signal_data[i], requires_grad=False).float())
    signal_results.append([label, signal_data[i], signal_prediction]) # save [label, true, prediction] for signal
    sig_mu.append(mu)
    sig_logvar.append(logvar)

# %% [markdown]
# ## KL AD Score

# %%
# Define AD score
def AD_score(mu, logvar):
    return -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp(), dim=1)

# %%
# compute loss value (true, predicted)
total_loss = []

total_loss.append(AD_score(bkg_mu, bkg_logvar).detach())
for i, signal_X in enumerate(signal_data):
    total_loss.append(AD_score(sig_mu[i], sig_logvar[i]).detach())

# %%
bin_size=100
labels = np.concatenate([['Background'], np.array(signal_labels)])
plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    plt.hist(total_loss[i], bins=bin_size, label=label, density = True, histtype='step', fill=False, linewidth=1.5)

plt.yscale('log')
plt.xlabel("Autoencoder Loss")
plt.ylabel("Probability (a.u.)")
plt.title('KL loss')
plt.legend(loc='best')
plt.show()

# %%
target_background = np.zeros(total_loss[0].shape[0])

plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    if i == 0: continue # background events

    trueVal = np.concatenate((np.ones(total_loss[i].shape[0]), target_background)) # anomaly=1, bkg=0
    predVal_loss = np.concatenate((total_loss[i], total_loss[0]))

    fpr_loss, tpr_loss, threshold_loss = roc_curve(trueVal, predVal_loss)

    auc_loss = auc(fpr_loss, tpr_loss)

    plt.plot(fpr_loss, tpr_loss, "-", label='%s (auc = %.1f%%)'%(label,auc_loss*100.), linewidth=1.5)

    plt.semilogx()
    plt.semilogy()
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    plt.legend(loc='center right')
    plt.grid(True)
    plt.tight_layout()
plt.plot(np.linspace(0, 1),np.linspace(0, 1), '--', color='0.75')
plt.axvline(0.00001, color='red', linestyle='dashed', linewidth=1) # threshold value for measuring anomaly detection efficiency
plt.title("ROC AE with KL AD Score")
plt.show()

# %% [markdown]
# ## MSE KL Score

# %%
# compute loss value (true, predicted)
total_loss = []
print(type(bkg_prediction))
total_loss.append(mse_loss(X_test, bkg_prediction.astype(np.float32)))
for i, signal_X in enumerate(signal_data):
    total_loss.append(mse_loss(signal_X,
                               signal_results[i][2].detach().numpy().astype(np.float32)))
# Out:
# <class 'numpy.ndarray'>

# %%
# compute loss value (true, predicted)
total_loss = []

total_loss.append(mse_loss(X_test, np.array(bkg_prediction)))
for i, signal_X in enumerate(signal_data):
    total_loss.append(mse_loss(signal_X,
                               signal_results[i][2].detach().numpy().astype(np.float32)))

# %%
bin_size=100
labels = np.concatenate([['Background'], np.array(signal_labels)])
plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    plt.hist(total_loss[i], bins=bin_size, label=label, density = True, histtype='step', fill=False, linewidth=1.5)

plt.yscale('log')
plt.xlabel("Autoencoder Loss")
plt.ylabel("Probability (a.u.)")
plt.title('MSE loss')
plt.legend(loc='best')
plt.show()

# %%
target_background = np.zeros(total_loss[0].shape[0])

plt.figure(figsize=(10,8))
for i, label in enumerate(labels):
    if i == 0: continue # background events

    trueVal = np.concatenate((np.ones(total_loss[i].shape[0]), target_background)) # anomaly=1, bkg=0
    predVal_loss = np.concatenate((total_loss[i], total_loss[0]))

    fpr_loss, tpr_loss, threshold_loss = roc_curve(trueVal, predVal_loss)

    auc_loss = auc(fpr_loss, tpr_loss)

    plt.plot(fpr_loss, tpr_loss, "-", label='%s (auc = %.1f%%)'%(label,auc_loss*100.), linewidth=1.5)

    plt.semilogx()
    plt.semilogy()
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    plt.legend(loc='center right')
    plt.grid(True)
    plt.tight_layout()
plt.plot(np.linspace(0, 1),np.linspace(0, 1), '--', color='0.75')
plt.axvline(0.00001, color='red', linestyle='dashed', linewidth=1) # threshold value for measuring anomaly detection efficiency
plt.title("ROC AE with MSE AD Score")
plt.show()
